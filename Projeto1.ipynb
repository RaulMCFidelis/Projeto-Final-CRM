# %% [markdown]
# <!-- Projeto Desenvolvido na Data Science Academy - www.datascienceacademy.com.br -->
# # <font color='blue'>IBPAD</font>
# ## <font color='blue'>Projeto Final Trainee CRM</font>
# ## <font color='blue'>Raul Maximiliano de Carvalho Fidelis</font>

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# %pip install -q -U watermark
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# O procedimento de instalação dos pacotes está no arquivo LEIAME.txt

# %%
# https://pypi.org/project/squarify/
# %pip install -q squarify
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import sklearn
import squarify
import pandas as pd
import seaborn as sns
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta

# %% [markdown]
# ## Carregando e Explorando os Dados

# %%
# Carrega o dataset
df_rmx = pd.read_csv("essenza_crm.csv", sep=";")

# %%
# Shape
df_rmx.shape
# Out:
# (5000, 24)

# %%
# Amostra de dados
df_rmx.head()
# Out:
#   cliente_id data_disparo dia_semana   canal           tipo_campanha  \
# 0   CLI00360   2024-03-05      Terça     SMS     Carrinho Abandonado
# 1   CLI01161   2024-08-07     Quarta    Push  Programa de Fidelidade
# 2   CLI01749   2024-03-18    Segunda     SMS     Carrinho Abandonado
# 3   CLI01010   2024-08-12    Segunda  E-mail             Aniversário
# 4   CLI01588   2025-05-25    Domingo     SMS      Conteúdo/Educativo
#
#   segmento_cliente         genero faixa_etaria opt_in_email opt_in_sms  ...  \
# 0          Inativo  Não informado        35-44          Sim        Sim  ...
# 1              VIP              F        35-44          Sim        Não  ...
# 2            Ativo              F        18-24          Não        Sim  ...
# 3            Ativo              M        45-54          Sim        Sim  ...
# 4            Ativo              F        25-34          Sim        Sim  ...
#
#   numero_disparos_30d dias_desde_ultima_compra frequencia_compras_historica  \
# 0                   4                      292                            4
# 1                  10                       56                           12
# 2                   5                       45                           14
# 3                   3                       17                           15
# 4                   2                       72                           15
#
#    ticket_medio_historico_brl  abriu  clicou  converteu  valor_compra_brl  \
# 0                       99.06    Sim     Não        Não               0.0
# 1                      616.48    Não     Não        Não               0.0
# 2                      171.31    Sim     Sim        Não               0.0
# 3                      266.37    Sim     Sim        Não               0.0
# 4                      243.77    Não     Não        Não               0.0
#
#   categoria_produto dias_ate_recompra
# 0               NaN               NaN
# 1               NaN               NaN
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN
#
# [5 rows x 24 columns]

# %%
df_rmx.opt_in_email.value_counts()
# Out:
# opt_in_email
# Sim    4548
# Não     452
# Name: count, dtype: int64

# %%
df_rmx.opt_in_email.replace('Sim', 1, inplace = True)
df_rmx.opt_in_email.replace('Não', 0, inplace = True)
# Out:
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\2800890923.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.opt_in_email.replace('Sim', 1, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\2800890923.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.opt_in_email.replace('Não', 0, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\2800890923.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_rmx.opt_in_email.replace('Não', 0, inplace = True)

# %%
df_rmx.opt_in_sms.value_counts()
# Out:
# opt_in_sms
# Sim    3254
# Não    1746
# Name: count, dtype: int64

# %%
df_rmx.opt_in_sms.replace('Sim', 1, inplace = True)
df_rmx.opt_in_sms.replace('Não', 0, inplace = True)
# Out:
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\344477126.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.opt_in_sms.replace('Sim', 1, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\344477126.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.opt_in_sms.replace('Não', 0, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\344477126.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_rmx.opt_in_sms.replace('Não', 0, inplace = True)

# %%
df_rmx.opt_in_push.value_counts()
# Out:
# opt_in_push
# Sim    3044
# Não    1956
# Name: count, dtype: int64

# %%
df_rmx.opt_in_push.replace('Sim', 1, inplace = True)
df_rmx.opt_in_push.replace('Não', 0, inplace = True)
# Out:
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\1195815490.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.opt_in_push.replace('Sim', 1, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\1195815490.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.opt_in_push.replace('Não', 0, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\1195815490.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_rmx.opt_in_push.replace('Não', 0, inplace = True)

# %%
df_rmx.teve_desconto.value_counts()
# Out:
# teve_desconto
# Não    3517
# Sim    1483
# Name: count, dtype: int64

# %%
df_rmx.teve_desconto.replace('Sim', 1, inplace = True)
df_rmx.teve_desconto.replace('Não', 0, inplace = True)
# Out:
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\1816953267.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.teve_desconto.replace('Sim', 1, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\1816953267.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.teve_desconto.replace('Não', 0, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\1816953267.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_rmx.teve_desconto.replace('Não', 0, inplace = True)

# %%
df_rmx.opt_in_whatsapp.value_counts()
# Out:
# opt_in_whatsapp
# Sim    3599
# Não    1401
# Name: count, dtype: int64

# %%
df_rmx.opt_in_whatsapp.replace('Sim', 1, inplace = True)
df_rmx.opt_in_whatsapp.replace('Não', 0, inplace = True)
# Out:
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\3542478519.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.opt_in_whatsapp.replace('Sim', 1, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\3542478519.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.opt_in_whatsapp.replace('Não', 0, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\3542478519.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_rmx.opt_in_whatsapp.replace('Não', 0, inplace = True)

# %%
df_rmx.abriu.value_counts()
# Out:
# abriu
# Não    3009
# Sim    1991
# Name: count, dtype: int64

# %%
df_rmx.abriu.replace('Sim', 1, inplace = True)
df_rmx.abriu.replace('Não', 0, inplace = True)
# Out:
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\320118595.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.abriu.replace('Sim', 1, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\320118595.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.abriu.replace('Não', 0, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\320118595.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_rmx.abriu.replace('Não', 0, inplace = True)

# %%
df_rmx.clicou.value_counts()
# Out:
# clicou
# Não    4231
# Sim     769
# Name: count, dtype: int64

# %%
df_rmx.clicou.replace('Sim', 1, inplace = True)
df_rmx.clicou.replace('Não', 0, inplace = True)
# Out:
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\2021910910.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.clicou.replace('Sim', 1, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\2021910910.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.clicou.replace('Não', 0, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\2021910910.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_rmx.clicou.replace('Não', 0, inplace = True)

# %%
df_rmx.converteu.value_counts()
# Out:
# converteu
# Não    4682
# Sim     318
# Name: count, dtype: int64

# %%
df_rmx.converteu.replace('Sim', 1, inplace = True)
df_rmx.converteu.replace('Não', 0, inplace = True)
# Out:
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\4021161556.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.converteu.replace('Sim', 1, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\4021161556.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rmx.converteu.replace('Não', 0, inplace = True)
# C:\Users\Raul\AppData\Local\Temp\ipykernel_43524\4021161556.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_rmx.converteu.replace('Não', 0, inplace = True)

# %%
df_rmx['data_disparo'] = pd.to_datetime(df_rmx['data_disparo'], format='%Y-%m-%d')

# %%
df_rmx['categoria_produto'] = df_rmx['categoria_produto'].fillna('Não Informado')

# %%
df_rmx['dias_ate_recompra'] = df_rmx['dias_ate_recompra'].fillna(0)

# %%
df_rmx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   cliente_id                    5000 non-null   object
#  1   data_disparo                  5000 non-null   datetime64[ns]
#  2   dia_semana                    5000 non-null   object
#  3   canal                         5000 non-null   object
#  4   tipo_campanha                 5000 non-null   object
#  5   segmento_cliente              5000 non-null   object
#  6   genero                        5000 non-null   object
#  7   faixa_etaria                  5000 non-null   object
#  8   opt_in_email                  5000 non-null   int64
#  9   opt_in_sms                    5000 non-null   int64
#  10  opt_in_push                   5000 non-null   int64
#  11  opt_in_whatsapp               5000 non-null   int64
#  12  teve_desconto                 5000 non-null   int64
#  13  pct_desconto                  5000 non-null   int64
#  14  numero_disparos_30d           5000 non-null   int64
#  15  dias_desde_ultima_compra      5000 non-null   int64
#  16  frequencia_compras_historica  5000 non-null   int64
#  17  ticket_medio_historico_brl    5000 non-null   float64
#  18  abriu                         5000 non-null   int64
#  19  clicou                        5000 non-null   int64
#  20  converteu                     5000 non-null   int64
#  21  valor_compra_brl              5000 non-null   float64
#  22  categoria_produto             5000 non-null   object
#  23  dias_ate_recompra             5000 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(12), object(8)
# memory usage: 937.6+ KB

# %%
df_rmx.head()
# Out:
#   cliente_id data_disparo dia_semana   canal           tipo_campanha  \
# 0   CLI00360   2024-03-05      Terça     SMS     Carrinho Abandonado
# 1   CLI01161   2024-08-07     Quarta    Push  Programa de Fidelidade
# 2   CLI01749   2024-03-18    Segunda     SMS     Carrinho Abandonado
# 3   CLI01010   2024-08-12    Segunda  E-mail             Aniversário
# 4   CLI01588   2025-05-25    Domingo     SMS      Conteúdo/Educativo
#
#   segmento_cliente         genero faixa_etaria  opt_in_email  opt_in_sms  ...  \
# 0          Inativo  Não informado        35-44             1           1  ...
# 1              VIP              F        35-44             1           0  ...
# 2            Ativo              F        18-24             0           1  ...
# 3            Ativo              M        45-54             1           1  ...
# 4            Ativo              F        25-34             1           1  ...
#
#    numero_disparos_30d  dias_desde_ultima_compra  \
# 0                    4                       292
# 1                   10                        56
# 2                    5                        45
# 3                    3                        17
# 4                    2                        72
#
#    frequencia_compras_historica  ticket_medio_historico_brl  abriu  clicou  \
# 0                             4                       99.06      1       0
# 1                            12                      616.48      0       0
# 2                            14                      171.31      1       1
# 3                            15                      266.37      1       1
# 4                            15                      243.77      0       0
#
#    converteu  valor_compra_brl  categoria_produto  dias_ate_recompra
# 0          0               0.0      Não Informado                0.0
# 1          0               0.0      Não Informado                0.0
# 2          0               0.0      Não Informado                0.0
# 3          0               0.0      Não Informado                0.0
# 4          0               0.0      Não Informado                0.0
#
# [5 rows x 24 columns]
